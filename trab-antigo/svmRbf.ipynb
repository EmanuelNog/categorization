# %%
import pandas as pd

dataSet = pd.read_csv('brain_stroke_formated.csv')  
#colunas
X = dataSet.loc[:,"gender":"smoking_status"].values
y = dataSet.loc[:,"stroke"].values

from sklearn.model_selection import train_test_split
#divisao do dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
#classificador
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
dataSet.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          3
# 1       1  80.0             0              1             1          3
# 2       0  49.0             0              0             1          3
# 3       0  79.0             1              0             1          4
# 4       1  81.0             0              0             1          3
#
#    Residence_type  avg_glucose_level   bmi  smoking_status           stroke
# 0               1             228.69  36.6               1  stroke_positive
# 1               0             105.92  32.5               2  stroke_positive
# 2               1             171.23  34.4               3  stroke_positive
# 3               0             174.12  24.0               2  stroke_positive
# 4               1             186.21  29.0               1  stroke_positive

# %%
y_desejado
# Out:
# array(['stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_positive', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_positive', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_positive',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative'], dtype=object)

# %%
y_previsto
# Out:
# array(['stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative', 'stroke_negative', 'stroke_negative',
#        'stroke_negative'], dtype=object)

# %%
#acuracia
from sklearn.metrics import accuracy_score
y_previsto = clf.predict(X_test)
y_desejado = y_test
accuracy_score(y_previsto, y_desejado)
# Out:
# 0.9578736208625878
